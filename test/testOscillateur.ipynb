# %% [markdown]
# <div style="width:90%;
#             margin:10px;
#             padding:8px;
#             border:2px solid #FF0000;
#             border-radius:20px;
#             font-weight:bold;
#             font-size:2.5em;
#             text-align:center;">
# The Double Oscillator Problem
# </div>

# %% [markdown]
# <div style="width:90%;
#             margin:9px;
#             font-size:1em;">
#
# *The Double Oscillator Problem:* The problem is to find the optimal control for a double oscillator system.
# The problem is inspired from : [Optimal bang-bang control of a mechanical double oscillator using averaging methods](https://cas.mines-paristech.fr/~petit/papers/mathmod2018/main.pdf) by Christophe Coudurier, Olivier Lepreux and Nicolas Petit.
# We solve the problem using the [JuMP](https://jump.dev/) and [OptimalControl](https://control-toolbox.org/OptimalControl.jl/stable/) packages in Julia then we compare the results.
#
# 1. [JuMP Formulation](#jump)
# 2. [OptimalControl Formulation](#oc)
# 3. [Comparison](#comp)
#
# </div>

# %%
import Pkg
Pkg.activate("..")
include("./utils.jl");
using OptimalControlProblems
using Plots
using MKL
import HSL_jll
nh = 500;
# Out:
#   Activating project at `~/ENSEEIHT/Stage/CTBenchmarks.jl`

# %% [markdown]
# ## 1. Solving with JuMP <a id='jump'></a>

# %%
using JuMP , Ipopt

OscillatorJMP = double_oscillator(JuMPBackend(); nh=nh)

set_optimizer(OscillatorJMP,Ipopt.Optimizer)
set_attribute(OscillatorJMP, "print_level", 5)
set_optimizer_attribute(OscillatorJMP,"tol",1e-8)
set_optimizer_attribute(OscillatorJMP,"constr_viol_tol",1e-6)
set_optimizer_attribute(OscillatorJMP,"max_iter",1000)
set_optimizer_attribute(OscillatorJMP,"mu_strategy","adaptive")
#set_attribute(OscillatorJMP, "hsllib", HSL_jll.libhsl_path)
#set_attribute(OscillatorJMP, "linear_solver", "ma57")
set_optimizer_attribute(OscillatorJMP, "print_timing_statistics", "yes")

# %%
println("Solving...")
optimize!(OscillatorJMP)
println()

# Display results
if termination_status(OscillatorJMP) == MOI.OPTIMAL
    println("  Solution is optimal")
elseif  termination_status(OscillatorJMP) == MOI.LOCALLY_SOLVED
    println("  (Local) solution found")
elseif termination_status(OscillatorJMP) == MOI.TIME_LIMIT && has_values(OscillatorJMP)
    println("  Solution is suboptimal due to a time limit, but a primal solution is available")
else
    error("  The model was not solved correctly.")
end
println("  objective value = ", objective_value(OscillatorJMP))
println()

tf = 2π
step = tf / nh

x1 = OscillatorJMP[:x1];
x2 = OscillatorJMP[:x2];
x3 = OscillatorJMP[:x3];
x4 = OscillatorJMP[:x4];

con_x1 = OscillatorJMP[:con_x1];
con_x2 = OscillatorJMP[:con_x2];
con_x3 = OscillatorJMP[:con_x3];
con_x4 = OscillatorJMP[:con_x4];


t = Vector((0:nh)*step); 

p = - [[ dual(con_x1[i]), dual(con_x2[i]), dual(con_x3[i]), dual(con_x4[i]) ] for i in 1:nh];
p = costateInterpolation(p, t);

x1 = Vector(value.(x1)) ;
x2 = Vector(value.(x2)) ;
x3 = Vector(value.(x3)) ;
x4 = Vector(value.(x4)) ;

u = OscillatorJMP[:u];
u = Vector(value.(u));

x =  [ [ x1[i], x2[i], x3[i], x4[i] ] for i in 1:nh+1];
# Out:
# Solving...
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.17, running with linear solver MUMPS 5.8.0.
#
# Number of nonzeros in equality constraint Jacobian...:    12002
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     2503
#
# Total number of variables............................:     2505
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:      501
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     2002
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 1.26e-04 0.00e+00   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  7.2852618e-02 1.39e-17 5.96e-05  -2.1 4.64e-02    -  9.98e-01 1.00e+00h  1
#    2  7.2852482e-02 9.95e-15 1.18e-08  -8.0 5.85e-05    -  9.90e-01 1.00e+00f  1
#    3  7.2852482e-02 2.04e-17 1.17e-10 -10.0 1.17e-06    -  1.00e+00 1.00e+00h  1
#    4  7.2852482e-02 1.50e-17 8.88e-16 -11.0 2.35e-10    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 4
#
#                                    (scaled)                 (unscaled)
# Objective...............:   7.2852481500422589e-02    7.2852481500422589e-02
# Dual infeasibility......:   8.8817841970012523e-16    8.8817841970012523e-16
# Constraint violation....:   1.4959439472278730e-17    1.4959439472278730e-17
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   1.0000002458763391e-11    1.0000002458763391e-11
# Overall NLP error.......:   1.0000002458763391e-11    1.0000002458763391e-11
#
#
# Number of objective function evaluations             = 5
# Number of objective gradient evaluations             = 5
# Number of equality constraint evaluations            = 5
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 5
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 4
# Total seconds in IPOPT (w/o function evaluations)    =      0.262
# Total seconds in NLP function evaluations            =      0.223
#
#
# Timing Statistics:
#
# OverallAlgorithm....................:      0.503 (sys:      0.017 wall:      0.485)
#  PrintProblemStatistics.............:      0.000 (sys:      0.000 wall:      0.000)
#  InitializeIterates.................:      0.169 (sys:      0.010 wall:      0.162)
#  UpdateHessian......................:      0.001 (sys:      0.000 wall:      0.001)
#  OutputIteration....................:      0.000 (sys:      0.000 wall:      0.000)
#  UpdateBarrierParameter.............:      0.038 (sys:      0.004 wall:      0.022)
#  ComputeSearchDirection.............:      0.008 (sys:      0.000 wall:      0.003)
#  ComputeAcceptableTrialPoint........:      0.009 (sys:      0.000 wall:      0.002)
#  AcceptTrialPoint...................:      0.000 (sys:      0.000 wall:      0.000)
#  CheckConvergence...................:      0.278 (sys:      0.003 wall:      0.294)
# PDSystemSolverTotal.................:      0.044 (sys:      0.004 wall:      0.023)
#  PDSystemSolverSolveOnce............:      0.043 (sys:      0.004 wall:      0.022)
#  ComputeResiduals...................:      0.001 (sys:      0.000 wall:      0.001)
#  StdAugSystemSolverMultiSolve.......:      0.115 (sys:      0.014 wall:      0.065)
#  LinearSystemScaling................:      0.000 (sys:      0.000 wall:      0.000)
#  LinearSystemSymbolicFactorization..:      0.027 (sys:      0.000 wall:      0.011)
#  LinearSystemFactorization..........:      0.000 (sys:      0.000 wall:      0.000)
#  LinearSystemBackSolve..............:      0.015 (sys:      0.002 wall:      0.010)
#  LinearSystemStructureConverter.....:      0.000 (sys:      0.000 wall:      0.000)
#   LinearSystemStructureConverterInit:      0.000 (sys:      0.000 wall:      0.000)
# QualityFunctionSearch...............:      0.001 (sys:      0.000 wall:      0.001)
# TryCorrector........................:      0.000 (sys:      0.000 wall:      0.000)
# Task1...............................:      0.000 (sys:      0.000 wall:      0.000)
# Task2...............................:      0.000 (sys:      0.000 wall:      0.000)
# Task3...............................:      0.000 (sys:      0.000 wall:      0.000)
# Task4...............................:      0.000 (sys:      0.000 wall:      0.000)
# Task5...............................:      0.000 (sys:      0.000 wall:      0.000)
# Task6...............................:      0.000 (sys:      0.000 wall:      0.000)
# Function Evaluations................:      0.218 (sys:      0.002 wall:      0.223)
#  Objective function.................:      0.090 (sys:      0.000 wall:      0.094)
#  Objective function gradient........:      0.000 (sys:      0.000 wall:      0.000)
#  Equality constraints...............:      0.126 (sys:      0.002 wall:      0.127)
#  Inequality constraints.............:      0.000 (sys:      0.000 wall:      0.000)
#  Equality constraint Jacobian.......:      0.001 (sys:      0.000 wall:      0.001)
#  Inequality constraint Jacobian.....:      0.000 (sys:      0.000 wall:      0.000)
#  Lagrangian Hessian.................:      0.000 (sys:      0.000 wall:      0.001)
#
# EXIT: Optimal Solution Found.
#
#   (Local) solution found
#   objective value = 0.07285248150042259

# %%
x1_plot = plot(t, [ x[i][1] for i in 1:nh+1 ], xlabel = "t", ylabel = "x1", legend = false)
x2_plot = plot(t, [ x[i][2] for i in 1:nh+1 ], xlabel = "t", ylabel = "x2", legend = false)
x3_plot = plot(t, [ x[i][3] for i in 1:nh+1 ], xlabel = "t", ylabel = "x3", legend = false)
x4_plot = plot(t, [ x[i][4] for i in 1:nh+1 ], xlabel = "t", ylabel = "x4", legend = false)
px1_plot = plot(t, [ p[i][1] for i in 1:nh+1], xlabel = "t", ylabel = "px1", legend = false)
px2_plot = plot(t, [ p[i][2] for i in 1:nh+1], xlabel = "t", ylabel = "px2", legend = false)
px3_plot = plot(t, [ p[i][3] for i in 1:nh+1], xlabel = "t", ylabel = "px3", legend = false)
px4_plot = plot(t, [ p[i][4] for i in 1:nh+1], xlabel = "t", ylabel = "px4", legend = false)

u_plot = plot(t, [ u[i] for i in 1:nh+1], xlabel = "t", ylabel = "u", legend = false)

layout = @layout [a b; c d; e f; g h ;p]
x_plot = plot(x1_plot, px1_plot, x2_plot, px2_plot, x3_plot, px3_plot, x4_plot, px4_plot, u_plot, layout = layout)
x_plot = plot!(x_plot, size = (700, 1000))
display(x_plot)

# %% [markdown]
# ## 2. Solving with OptimalControl <a id='oc'></a>

# %%
using OptimalControl, NLPModelsIpopt
docp, OscillatorOC = double_oscillator(OptimalControlBackend(); nh=nh);
# Out:
# WARNING: using OptimalControl.Model in module Main conflicts with an existing identifier.

# %%
# Solve the problem
nlp_sol = NLPModelsIpopt.ipopt(
    OscillatorOC;
    print_level=5,
    tol=1e-8,
    mu_strategy="adaptive",
    sb="yes",
    constr_viol_tol=1e-6,
    max_iter=1000,
    print_timing_statistics="yes",
    #linear_solver="ma57",
    #hsllib=HSL_jll.libhsl_path,
)
# Out:
# This is Ipopt version 3.14.17, running with linear solver MUMPS 5.8.0.
#
# Number of nonzeros in equality constraint Jacobian...:    15003
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     2004
#
# Total number of variables............................:     3006
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:      501
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     2503
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.0000000e-01 1.00e-01 1.26e-03   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1 -2.8382044e-02 1.97e-04 2.28e-04  -2.1 1.53e-01    -  9.97e-01 1.00e+00h  1
#    2  7.0070521e-03 1.05e-05 1.96e-06  -3.3 3.92e-02    -  9.96e-01 1.00e+00h  1
#    3 -8.7430899e-03 2.27e-05 1.70e-08  -4.8 6.43e-02    -  1.00e+00 1.00e+00h  1
#    4  8.6447169e-04 2.94e-07 1.50e-10  -6.5 9.61e-03    -  1.00e+00 1.00e+00h  1
#    5  9.1092149e-04 2.28e-11 2.47e-11 -11.0 8.24e-05    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 5
#
#                                    (scaled)                 (unscaled)
# Objective...............:   9.1092149184368956e-04    9.1092149184368956e-04
# Dual infeasibility......:   2.4710190680479954e-11    2.4710190680479954e-11
# Constraint violation....:   2.2833655901119441e-11    2.2833655901119441e-11
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   1.1405480246088384e-10    1.1405480246088384e-10
# Overall NLP error.......:   1.1405480246088384e-10    1.1405480246088384e-10
#
#
# Number of objective function evaluations             = 6
# Number of objective gradient evaluations             = 6
# Number of equality constraint evaluations            = 6
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 6
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 5
# Total seconds in IPOPT (w/o function evaluations)    =      3.378
# Total seconds in NLP function evaluations            =      8.783
#
#
# Timing Statistics:
#
# OverallAlgorithm....................:     10.924 (sys:      0.295 wall:     12.161)
#  PrintProblemStatistics.............:      0.000 (sys:      0.000 wall:      0.000)
#  InitializeIterates.................:      3.083 (sys:      0.012 wall:      3.354)
#  UpdateHessian......................:      6.779 (sys:      0.281 wall:      7.653)
#  OutputIteration....................:      0.000 (sys:      0.000 wall:      0.000)
#  UpdateBarrierParameter.............:      0.017 (sys:      0.000 wall:      0.019)
#  ComputeSearchDirection.............:      0.003 (sys:      0.001 wall:      0.003)
#  ComputeAcceptableTrialPoint........:      0.001 (sys:      0.000 wall:      0.002)
#  AcceptTrialPoint...................:      0.000 (sys:      0.000 wall:      0.000)
#  CheckConvergence...................:      1.040 (sys:      0.001 wall:      1.129)
# PDSystemSolverTotal.................:      0.018 (sys:      0.001 wall:      0.020)
#  PDSystemSolverSolveOnce............:      0.017 (sys:      0.001 wall:      0.019)
#  ComputeResiduals...................:      0.000 (sys:      0.000 wall:      0.001)
#  StdAugSystemSolverMultiSolve.......:      0.025 (sys:      0.001 wall:      0.028)
#  LinearSystemScaling................:      0.000 (sys:      0.000 wall:      0.000)
#  LinearSystemSymbolicFactorization..:      0.005 (sys:      0.000 wall:      0.005)
#  LinearSystemFactorization..........:      0.000 (sys:      0.000 wall:      0.000)
#  LinearSystemBackSolve..............:      0.006 (sys:      0.000 wall:      0.007)
#  LinearSystemStructureConverter.....:      0.000 (sys:      0.000 wall:      0.000)
#   LinearSystemStructureConverterInit:      0.000 (sys:      0.000 wall:      0.000)
# QualityFunctionSearch...............:      0.001 (sys:      0.000 wall:      0.001)
# TryCorrector........................:      0.000 (sys:      0.000 wall:      0.000)
# Task1...............................:      0.000 (sys:      0.000 wall:      0.000)
# Task2...............................:      0.000 (sys:      0.000 wall:      0.000)
# Task3...............................:      0.000 (sys:      0.000 wall:      0.000)
# Task4...............................:      0.000 (sys:      0.000 wall:      0.000)
# Task5...............................:      0.000 (sys:      0.000 wall:      0.000)
# Task6...............................:      0.000 (sys:      0.000 wall:      0.000)
# Function Evaluations................:      7.821 (sys:      0.282 wall:      8.783)
#  Objective function.................:      0.054 (sys:      0.000 wall:      0.059)
#  Objective function gradient........:      0.000 (sys:      0.000 wall:      0.000)
#  Equality constraints...............:      0.981 (sys:      0.000 wall:      1.063)
#  Inequality constraints.............:      0.000 (sys:      0.000 wall:      0.000)
#  Equality constraint Jacobian.......:      0.006 (sys:      0.001 wall:      0.008)
#  Inequality constraint Jacobian.....:      0.000 (sys:      0.000 wall:      0.000)
#  Lagrangian Hessian.................:      6.779 (sys:      0.281 wall:      7.653)
#
# EXIT: Optimal Solution Found.
# "Execution stats: first-order stationary"

# %%
# Plot results
sol = build_OCP_solution(docp; primal=nlp_sol.solution, dual=nlp_sol.multipliers)
plot(sol)

# %% [markdown]
# ## 3. Comparison <a id='comp'></a>

# %%
p1 = plot(plot(sol)[1],line = 2)
p1 = plot!(t, [ x[i][1] for i in 1:nh+1 ], xlabel = "t", ylabel = "x1", legend = false,line = 2, color = "red",linestyle=:dash)

p3 = plot(plot(sol)[2],line = 2)
p3 = plot!(t, [ x[i][2] for i in 1:nh+1 ], xlabel = "t", ylabel = "x2", legend = false,line = 2, color = "red",linestyle=:dash)

p5 = plot(plot(sol)[3],line = 2)
p5 = plot!(t, [ x[i][3] for i in 1:nh+1 ], xlabel = "t", ylabel = "x3", legend = false,line = 2, color = "red",linestyle=:dash)

p7 = plot(plot(sol)[4],line = 2)
p7 = plot!(t, [ x[i][4] for i in 1:nh+1 ], xlabel = "t", ylabel = "x4", legend = false,line = 2, color = "red",linestyle=:dash)

p2 = plot(plot(sol)[5],line = 2)
p2 = plot!(t, [ p[i][1] for i in 1:nh+1 ], xlabel = "t", ylabel = "px1", legend = false,line = 2, color = "red",linestyle=:dash)

p4 = plot(plot(sol)[6],line = 2)
p4 = plot!(t, [ p[i][2] for i in 1:nh+1 ], xlabel = "t", ylabel = "px2", legend = false,line = 2, color = "red",linestyle=:dash)

p6 = plot(plot(sol)[7],line = 2)
p6 = plot!(t, [ p[i][3] for i in 1:nh+1 ], xlabel = "t", ylabel = "px3", legend = false,line = 2, color = "red",linestyle=:dash)

p8 = plot(plot(sol)[8],line = 2)
p8 = plot!(t, [ p[i][4] for i in 1:nh+1 ], xlabel = "t", ylabel = "px4", legend = false,line = 2, color = "red",linestyle=:dash)

p9 = plot(plot(sol)[9] , label ="OC",line = 2)
p9 = plot!(t, [u[i] for i in 1:nh+1 ], xlabel = "t", ylabel = "u", legend = false, label = "JuMP",line = 2, color = "red",linestyle=:dash)
p9 = plot!(legend=:outerbottom, legendcolumns=2)

layout = @layout [a b; c d; e f; g h; k]
x_plot = plot(p1, p2, p3, p4, p5, p6, p7 , p8, p9, layout = layout, size = (800, 1000))

display(x_plot)

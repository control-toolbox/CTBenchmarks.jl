# %% [markdown]
# <div style="width:90%;
#             margin:10px;
#             padding:8px;
#             border:2px solid #FF0000;
#             border-radius:20px;
#             font-weight:bold;
#             font-size:2.5em;
#             text-align:center;">
# The Dielectrophoretic Particle Problem
# </div>

# %% [markdown]
# <div style="width:90%;
#             margin:9px;
#             font-size:1em;">
#
# *The Dielectrophoretic Particle Problem:* This problem consists of a dielectrophoretic particle system. The goal is to find the trajectory that minimize the time taken for the particle to travel between two points.
# The problem is inspired from [Time-optimal control of a particle in a dielectrophoretic
# system](https://minesparis-psl.hal.science/hal-00531113/document) by Chang, D. E., Petit, N., & Rouchon, P. (2006). IEEE Transactions on Automatic Control, 51(7), 1100-1114.
#
# We solve the problem using the [JuMP](https://jump.dev/) and [OptimalControl](https://control-toolbox.org/OptimalControl.jl/stable/) packages in Julia then we compare the results.
#
# 1. [JuMP Formulation](#jump)
# 2. [OptimalControl Formulation](#oc)
# 3. [Comparison](#comp)
#
# </div>

# %%
import Pkg
Pkg.activate("..");
include("./utils.jl");
# Out:
#   Activating project at `c:\Users\hajje\Dropbox\PC\Desktop\Stage\COTS`

# %% [markdown]
# ## 1. Solving with JuMP <a id='jump'></a>

# %%
using JuMP , Ipopt
import HSL_jll
include("../Problems/JuMP/particle_JMP.jl")
nh=300
ParticleJMP = dielectrophoretic_particle_JMP(;nh=nh);

set_optimizer(ParticleJMP,Ipopt.Optimizer)
set_attribute(ParticleJMP, "print_level", 5)
set_optimizer_attribute(ParticleJMP,"tol",1e-8)
set_optimizer_attribute(ParticleJMP,"constr_viol_tol",1e-6)
set_optimizer_attribute(ParticleJMP,"max_iter",1000)
set_optimizer_attribute(ParticleJMP,"mu_strategy","adaptive")
set_attribute(ParticleJMP, "hsllib", HSL_jll.libhsl_path)
set_attribute(ParticleJMP, "linear_solver", "ma57")
set_optimizer_attribute(ParticleJMP, "print_timing_statistics", "yes")

# %%
println("Solving...")
optimize!(ParticleJMP)
println()

# Display results
if termination_status(ParticleJMP) == MOI.OPTIMAL
    println("  Solution is optimal")
elseif  termination_status(ParticleJMP) == MOI.LOCALLY_SOLVED
    println("  (Local) solution found")
elseif termination_status(ParticleJMP) == MOI.TIME_LIMIT && has_values(ParticleJMP)
    println("  Solution is suboptimal due to a time limit, but a primal solution is available")
else
    error("  The model was not solved correctly.")
end
println("  objective value = ", objective_value(ParticleJMP))
println()
# Out:
# Solving...
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.14, running with linear solver ma57.
#
# Number of nonzeros in equality constraint Jacobian...:     5103
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     5700
#
# Total number of variables............................:      904
#                      variables with only lower bounds:        1
#                 variables with lower and upper bounds:      301
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      603
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.0000000e+00 1.00e+00 0.00e+00   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.1650969e-02 1.16e-02 1.64e+00  -6.0 1.00e+00    -  4.95e-01 9.88e-01h  1
#    2  1.1649979e-04 1.16e-02 2.09e+04  -7.8 1.87e+02   2.0 5.29e-05 6.45e-04h  1
#    3  8.2955510e-04 1.16e-02 1.21e+05   0.4 3.64e+04    -  3.58e-06 5.08e-05f  1
#    4  9.2796195e-04 1.16e-02 1.21e+05   0.5 1.85e+03   1.5 1.69e-04 1.00e-05h  1
#    5  1.0371946e-03 1.16e-02 1.21e+05   0.7 4.41e+02   1.9 7.22e-03 1.26e-05h  1
#    6  2.1267763e-03 1.16e-02 1.17e+05   1.7 1.54e+03   1.5 1.26e-04 1.16e-04h  1
#    7  2.4412866e-03 1.16e-02 9.54e+04   1.7 1.12e+03   1.9 1.00e+00 2.42e-05h  1
#    8  8.2499630e-02 1.15e-02 4.50e+05  -3.1 9.40e+01    -  2.40e-04 7.96e-03h  1
#    9  3.0209094e-01 1.13e-02 9.26e+04   3.0 5.37e+01    -  9.88e-04 2.36e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  7.0805000e-01 1.07e-02 8.42e+04   3.0 1.09e+01   3.2 8.80e-02 4.98e-02h  1
#   11  4.6788103e+00 1.98e-02 6.58e+04   3.0 7.76e+00   3.7 6.13e-01 5.12e-01f  1
#   12  9.4169598e+00 8.70e-03 4.42e+04   3.0 4.74e+00    -  5.62e-01 1.00e+00f  1
#   13  1.0436811e+01 6.26e-04 1.01e+05   2.8 1.02e+00   5.0 1.00e+00 1.00e+00h  1
#   14  1.0763135e+01 8.39e-05 1.36e+04   2.7 3.26e-01   4.5 8.84e-01 1.00e+00f  1
#   15  1.0787934e+01 2.85e-06 2.84e+01   0.6 2.48e-02    -  9.91e-01 1.00e+00f  1
#   16  1.0772166e+01 1.22e-06 7.97e-01  -5.2 1.58e-02    -  9.70e-01 1.00e+00f  1
#   17  1.2959222e+01 2.79e-02 2.24e-01  -0.7 2.19e+00    -  7.51e-01 1.00e+00f  1
#   18  1.7781184e+01 2.25e-03 1.64e-01  -0.8 4.82e+00    -  1.00e+00 1.00e+00f  1
#   19  1.3310896e+01 1.14e-03 8.08e-02  -1.5 4.47e+00    -  1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  9.9741445e+00 1.28e-03 9.62e-02  -2.3 3.34e+00    -  1.00e+00 1.00e+00f  1
#   21  8.3239760e+00 7.83e-04 6.62e-02  -3.3 1.65e+00    -  1.00e+00 1.00e+00f  1
#   22  7.8206375e+00 2.06e-04 1.47e-02  -4.9 5.03e-01    -  1.00e+00 1.00e+00f  1
#   23  7.8082845e+00 3.87e-05 1.28e-03  -5.7 6.14e-02    -  1.00e+00 9.43e-01h  1
#   24  7.8110500e+00 8.87e-06 8.19e-05  -6.1 2.49e-02    -  1.00e+00 9.72e-01h  1
#   25  7.8113482e+00 1.93e-06 8.32e-06  -6.8 1.08e-02    -  1.00e+00 9.96e-01h  1
#   26  7.8113452e+00 4.04e-07 1.22e-06  -8.0 4.96e-03    -  1.00e+00 9.99e-01h  1
#   27  7.8113452e+00 7.64e-08 1.69e-07  -9.2 2.39e-03    -  1.00e+00 1.00e+00h  1
#   28  7.8113452e+00 1.39e-08 2.70e-08 -10.3 1.17e-03    -  1.00e+00 1.00e+00h  1
#   29  7.8113452e+00 3.25e-09 6.38e-09 -11.0 5.82e-04    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  7.8113451e+00 7.89e-10 1.54e-09 -11.0 2.87e-04    -  1.00e+00 1.00e+00h  1
#   31  7.8113451e+00 1.75e-10 3.34e-10 -11.0 1.35e-04    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 31
#
#                                    (scaled)                 (unscaled)
# Objective...............:   7.8113451375435856e+00    7.8113451375435856e+00
# Dual infeasibility......:   3.3392511871627750e-10    3.3392511871627750e-10
# Constraint violation....:   1.7527135298678331e-10    1.7527135298678331e-10
# Variable bound violation:   9.7872123738795835e-09    9.7872123738795835e-09
# Complementarity.........:   2.7974630575698562e-09    2.7974630575698562e-09
# Overall NLP error.......:   2.7974630575698562e-09    2.7974630575698562e-09
#
#
# Number of objective function evaluations             = 32
# Number of objective gradient evaluations             = 32
# Number of equality constraint evaluations            = 32
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 32
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 31
# Total seconds in IPOPT (w/o function evaluations)    =      0.051
# Total seconds in NLP function evaluations            =      0.974
#
#
# Timing Statistics:
#
# OverallAlgorithm....................:      1.026 (sys:      0.000 wall:      1.025)
#  PrintProblemStatistics.............:      0.000 (sys:      0.000 wall:      0.000)
#  InitializeIterates.................:      0.017 (sys:      0.000 wall:      0.017)
#  UpdateHessian......................:      0.968 (sys:      0.000 wall:      0.969)
#  OutputIteration....................:      0.002 (sys:      0.000 wall:      0.001)
#  UpdateBarrierParameter.............:      0.011 (sys:      0.000 wall:      0.015)
#  ComputeSearchDirection.............:      0.005 (sys:      0.000 wall:      0.006)
#  ComputeAcceptableTrialPoint........:      0.007 (sys:      0.000 wall:      0.005)
#  AcceptTrialPoint...................:      0.000 (sys:      0.000 wall:      0.000)
#  CheckConvergence...................:      0.016 (sys:      0.000 wall:      0.013)
# PDSystemSolverTotal.................:      0.012 (sys:      0.000 wall:      0.017)
#  PDSystemSolverSolveOnce............:      0.012 (sys:      0.000 wall:      0.016)
#  ComputeResiduals...................:      0.000 (sys:      0.000 wall:      0.001)
#  StdAugSystemSolverMultiSolve.......:      0.017 (sys:      0.000 wall:      0.022)
#  LinearSystemScaling................:      0.000 (sys:      0.000 wall:      0.000)
#  LinearSystemSymbolicFactorization..:      0.003 (sys:      0.000 wall:      0.003)
#  LinearSystemFactorization..........:      0.011 (sys:      0.000 wall:      0.011)
#  LinearSystemBackSolve..............:      0.000 (sys:      0.000 wall:      0.004)
#  LinearSystemStructureConverter.....:      0.000 (sys:      0.000 wall:      0.000)
#   LinearSystemStructureConverterInit:      0.000 (sys:      0.000 wall:      0.000)
# QualityFunctionSearch...............:      0.001 (sys:      0.000 wall:      0.001)
# TryCorrector........................:      0.000 (sys:      0.000 wall:      0.000)
# Task1...............................:      0.000 (sys:      0.000 wall:      0.000)
# Task2...............................:      0.000 (sys:      0.000 wall:      0.000)
# Task3...............................:      0.000 (sys:      0.000 wall:      0.000)
# Task4...............................:      0.000 (sys:      0.000 wall:      0.000)
# Task5...............................:      0.000 (sys:      0.000 wall:      0.000)
# Task6...............................:      0.000 (sys:      0.000 wall:      0.000)
# Function Evaluations................:      0.975 (sys:      0.000 wall:      0.974)
#  Objective function.................:      0.000 (sys:      0.000 wall:      0.000)
#  Objective function gradient........:      0.000 (sys:      0.000 wall:      0.000)
#  Equality constraints...............:      0.004 (sys:      0.000 wall:      0.003)
#  Inequality constraints.............:      0.000 (sys:      0.000 wall:      0.000)
#  Equality constraint Jacobian.......:      0.003 (sys:      0.000 wall:      0.002)
#  Inequality constraint Jacobian.....:      0.000 (sys:      0.000 wall:      0.000)
#  Lagrangian Hessian.................:      0.968 (sys:      0.000 wall:      0.969)
#
# EXIT: Optimal Solution Found.
#
#   (Local) solution found
#   objective value = 7.811345137543586

# %%
# Retrieves values of variables
x_ = ParticleJMP[:x];
y = ParticleJMP[:y];

con_x = ParticleJMP[:con_x];
con_y = ParticleJMP[:con_y];

tf = ParticleJMP[:tf];
Δtt = value.(tf)/nh;
t = Vector((0:nh)*Δtt); 

p = - [[ dual(con_x[i]), dual(con_y[i])] for i in 1:nh];
p = costateInterpolation(p, t);

x_ = Vector(value.(x_)) ;
y = Vector(value.(y)) ;

x =  [ [ x_[i], y[i]] for i in 1:nh+1];

u = Vector(value.(ParticleJMP[:u])) ;

# %%
using Plots

x_plot = plot(t, [ x[i][1] for i in 1:nh+1 ], xlabel = "t", ylabel = "x", legend = false)
y_plot = plot(t, [ x[i][2] for i in 1:nh+1 ], xlabel = "t", ylabel = "y", legend = false)
px_plot = plot(t, [ p[i][1] for i in 1:nh+1 ], xlabel = "t", ylabel = "px", legend = false)
py_plot = plot(t, [ p[i][2] for i in 1:nh+1 ], xlabel = "t", ylabel = "py", legend = false)
u_plot = plot(t, [ u[i] for i in 1:nh+1 ], xlabel = "t", ylabel = "u", legend = false)

layout = @layout [a b; c d; g]

x_plot = plot(x_plot, px_plot, y_plot, py_plot, u_plot, layout = layout)
x_plot = plot!(x_plot, size = (700, 600))
display(x_plot)

# %%
plot(
    x_,
    y;
    linewidth = 2,
    legend = nothing,
    title = "Particle",
    xlabel = "x",
    ylabel = "y",
)

# %% [markdown]
# ## 2. Solving with OptimalControl <a id='oc'></a>

# %%
using OptimalControl
using NLPModelsIpopt
include("../Problems/OptimalControl/particle_OC.jl")
ParticleOC = dielectrophoretic_particle_OC();

# %%
init = dielectrophoretic_particle_init(;nh=nh-1)
# Out:
# (state = [1.0, 1.0], control = 0.0, variable = 1.0)

# %%
import HSL_jll
# Solve the problem
sol = OptimalControl.solve(ParticleOC,init=init, grid_size=nh-1,
            linear_solver="ma57",hsllib=HSL_jll.libhsl_path, print_timing_statistics="yes")
# Out:
# Method = (:direct, :adnlp, :ipopt)
# This is Ipopt version 3.14.14, running with linear solver ma57.
#
# Number of nonzeros in equality constraint Jacobian...:     3591
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     1200
#
# Total number of variables............................:      901
#                      variables with only lower bounds:        1
#                 variables with lower and upper bounds:      300
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      601
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.0000000e+00 1.00e+00 0.00e+00   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.1656487e-02 1.17e-02 1.63e+00  -6.0 1.00e+00    -  4.95e-01 9.88e-01h  1
#    2  1.1655497e-04 1.16e-02 2.59e+04  -7.8 1.87e+02   2.0 5.29e-05 7.20e-04h  1
#    3  8.0136250e-04 1.16e-02 1.35e+05   0.4 3.37e+04    -  4.29e-06 5.45e-05f  1
#    4  8.9733179e-04 1.16e-02 1.35e+05   0.6 1.70e+03   1.5 2.29e-04 1.08e-05h  1
#    5  1.0801376e-03 1.16e-02 1.34e+05   0.8 4.32e+02   1.9 7.91e-03 2.29e-05h  1
#    6  2.0096354e-03 1.16e-02 1.31e+05   1.7 1.47e+03   1.5 1.38e-04 1.05e-04h  1
#    7  2.7226672e-03 1.16e-02 1.06e+05   1.7 9.08e+02   1.9 1.00e+00 6.54e-05h  1
#    8  7.8508240e-02 1.16e-02 4.12e+05  -3.2 9.11e+01    -  2.85e-04 8.02e-03h  1
#    9  3.0220939e-01 1.13e-02 7.53e+04   3.0 5.26e+01    -  1.14e-03 2.48e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  5.2327274e-01 1.10e-02 7.06e+04   3.0 1.74e+01   3.2 6.90e-02 2.61e-02h  1
#   11  9.4089626e-01 1.04e-02 2.63e+04   2.4 8.72e+00   3.7 1.00e+00 4.79e-02h  1
#   12  3.9650659e+00 8.51e-03 3.15e+04   3.0 8.27e+00   3.2 1.32e-01 3.66e-01f  1
#   13  7.5629060e+00 2.33e-02 2.76e+04   3.0 6.86e+00    -  6.57e-01 5.24e-01f  1
#   14  8.0119428e+00 3.20e-02 2.55e+04   3.0 1.76e+01   3.6 5.80e-02 1.04e-01f  1
#   15  1.1206928e+01 2.29e-02 3.71e+04   3.0 3.19e+00   4.0 5.80e-01 1.00e+00f  1
#   16  1.2029156e+01 1.36e-04 1.26e+03   1.9 8.22e-01    -  9.91e-01 1.00e+00h  1
#   17  1.2017762e+01 9.90e-08 4.49e+01   0.1 1.14e-02   3.6 9.92e-01 1.00e+00f  1
#   18  1.2017546e+01 4.65e-10 2.55e-01  -1.6 2.16e-04   3.1 9.96e-01 1.00e+00h  1
#   19  7.2916425e+00 2.70e-02 1.46e-01  -7.5 4.73e+00    -  2.96e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  9.2309063e+00 1.51e-03 1.57e-02  -2.1 1.94e+00    -  9.94e-01 1.00e+00h  1
#   21  8.0899321e+00 3.39e-04 2.44e-02  -8.1 1.14e+00    -  9.23e-01 1.00e+00f  1
#   22  7.8317899e+00 6.16e-05 4.75e-03  -4.9 2.58e-01    -  1.00e+00 1.00e+00f  1
#   23  7.8109572e+00 2.09e-05 3.60e-04  -6.0 4.64e-02    -  1.00e+00 9.66e-01h  1
#   24  7.8112598e+00 5.87e-06 5.50e-05  -6.5 1.97e-02    -  1.00e+00 9.77e-01h  1
#   25  7.8113526e+00 1.30e-06 4.45e-06  -7.0 8.75e-03    -  1.00e+00 9.99e-01h  1
#   26  7.8113460e+00 2.71e-07 6.33e-07  -8.2 4.05e-03    -  1.00e+00 1.00e+00h  1
#   27  7.8113454e+00 4.97e-08 8.73e-08  -9.4 1.94e-03    -  1.00e+00 1.00e+00h  1
#   28  7.8113453e+00 8.32e-09 1.42e-08 -11.0 9.10e-04    -  1.00e+00 1.00e+00h  1
#   29  7.8113452e+00 1.36e-09 2.26e-09 -11.0 3.76e-04    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  7.8113452e+00 9.28e-11 1.36e-10 -11.0 9.82e-05    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 30
#
#                                    (scaled)                 (unscaled)
# Objective...............:   7.8113452338184421e+00    7.8113452338184421e+00
# Dual infeasibility......:   1.3611834776912864e-10    1.3611834776912864e-10
# Constraint violation....:   9.2848173594006767e-11    9.2848173594006767e-11
# Variable bound violation:   9.7879200300354796e-09    9.7879200300354796e-09
# Complementarity.........:   1.4865580502762067e-09    1.4865580502762067e-09
# Overall NLP error.......:   1.4865580502762067e-09    1.4865580502762067e-09
#
#
# Number of objective function evaluations             = 31
# Number of objective gradient evaluations             = 31
# Number of equality constraint evaluations            = 31
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 31
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 30
# Total seconds in IPOPT (w/o function evaluations)    =      1.236
# Total seconds in NLP function evaluations            =      1.324
#
#
# Timing Statistics:
#
# OverallAlgorithm....................:      2.561 (sys:      0.000 wall:      2.560)
#  PrintProblemStatistics.............:      0.000 (sys:      0.000 wall:      0.000)
#  InitializeIterates.................:      1.208 (sys:      0.000 wall:      1.208)
#  UpdateHessian......................:      0.748 (sys:      0.000 wall:      0.745)
#  OutputIteration....................:      0.002 (sys:      0.000 wall:      0.002)
#  UpdateBarrierParameter.............:      0.014 (sys:      0.000 wall:      0.018)
#  ComputeSearchDirection.............:      0.001 (sys:      0.000 wall:      0.003)
#  ComputeAcceptableTrialPoint........:      0.057 (sys:      0.000 wall:      0.054)
#  AcceptTrialPoint...................:      0.002 (sys:      0.000 wall:      0.001)
#  CheckConvergence...................:      0.529 (sys:      0.000 wall:      0.529)
# PDSystemSolverTotal.................:      0.008 (sys:      0.000 wall:      0.017)
#  PDSystemSolverSolveOnce............:      0.007 (sys:      0.000 wall:      0.016)
#  ComputeResiduals...................:      0.001 (sys:      0.000 wall:      0.001)
#  StdAugSystemSolverMultiSolve.......:      0.013 (sys:      0.000 wall:      0.021)
#  LinearSystemScaling................:      0.000 (sys:      0.000 wall:      0.000)
#  LinearSystemSymbolicFactorization..:      0.003 (sys:      0.000 wall:      0.003)
#  LinearSystemFactorization..........:      0.006 (sys:      0.000 wall:      0.010)
#  LinearSystemBackSolve..............:      0.002 (sys:      0.000 wall:      0.005)
#  LinearSystemStructureConverter.....:      0.000 (sys:      0.000 wall:      0.000)
#   LinearSystemStructureConverterInit:      0.000 (sys:      0.000 wall:      0.000)
# QualityFunctionSearch...............:      0.003 (sys:      0.000 wall:      0.002)
# TryCorrector........................:      0.000 (sys:      0.000 wall:      0.000)
# Task1...............................:      0.001 (sys:      0.000 wall:      0.000)
# Task2...............................:      0.000 (sys:      0.000 wall:      0.001)
# Task3...............................:      0.000 (sys:      0.000 wall:      0.000)
# Task4...............................:      0.000 (sys:      0.000 wall:      0.000)
# Task5...............................:      0.000 (sys:      0.000 wall:      0.000)
# Task6...............................:      0.000 (sys:      0.000 wall:      0.000)
# Function Evaluations................:      1.333 (sys:      0.000 wall:      1.324)
#  Objective function.................:      0.040 (sys:      0.000 wall:      0.040)
#  Objective function gradient........:      0.000 (sys:      0.000 wall:      0.001)
#  Equality constraints...............:      0.436 (sys:      0.000 wall:      0.432)
#  Inequality constraints.............:      0.000 (sys:      0.000 wall:      0.000)
#  Equality constraint Jacobian.......:      0.109 (sys:      0.000 wall:      0.107)
#  Inequality constraint Jacobian.....:      0.000 (sys:      0.000 wall:      0.000)
#  Lagrangian Hessian.................:      0.748 (sys:      0.000 wall:      0.744)
#
# EXIT: Optimal Solution Found.
# CTBase.OptimalControlSolution

# %%
plot(sol)

# %%
using JuMP
t_f = sol.variable
Δt = ones(nh)*(t_f/(nh))
ts = cumsum([0; value.(Δt)])[1:end]
xOC = [sol.state(t) for t in ts]
pos_x = [xOC[i][1] for i in 1:length(x)]
pos_y = [xOC[i][2] for i in 1:length(x)]
plot(
    pos_x,
    pos_y;
    linewidth = 2,
    legend = nothing,
    title = "Particle",
    xlabel = "x",
    ylabel = "y",
)

# %% [markdown]
# ## 3. Comparison <a id='comp'></a>

# %%
using Plots
px = plot(plot(sol)[1],line = 2)
px = plot!(t, [ x[i][1] for i in 1:nh+1 ], xlabel = "t", ylabel = "x", legend = false,line = 2, color = "red",linestyle=:dash)

py = plot(plot(sol)[2],line = 2)
py = plot!(t, [ x[i][2] for i in 1:nh+1 ], xlabel = "t", ylabel = "y", legend = false,line = 2, color = "red",linestyle=:dash)

ppx = plot(plot(sol)[3],line = 2)
ppx = plot!(t, [ p[i][1] for i in 1:nh+1 ], xlabel = "t", ylabel = "px", legend = false,line = 2, color = "red",linestyle=:dash)

ppy = plot(plot(sol)[4],line = 2)
ppy = plot!(t, [ p[i][2] for i in 1:nh+1 ], xlabel = "t", ylabel = "py", legend = false,line = 2, color = "red",linestyle=:dash)

p9 = plot(plot(sol)[5] , label ="OC",line = 2)
p9 = plot!(t, [u[i] for i in 1:nh+1 ], xlabel = "t", ylabel = "u", legend = false, label = "JuMP",line = 2, color = "red",linestyle=:dash)
p9 = plot!(legend=:outerbottom, legendcolumns=2)

layout = @layout [a b; c d; k]
x_plot = plot(px, ppx, py, ppy, p9, layout = layout, size = (700, 600))

display(x_plot)

# %% [markdown]
# <div style="width:90%;
#             margin:10px;
#             padding:8px;
#             border:2px solid #FF0000;
#             border-radius:20px;
#             font-weight:bold;
#             font-size:2.5em;
#             text-align:center;">
# The Goddard Rocket Problem
# </div>

# %% [markdown]
# <div style="width:90%;
#             margin:9px;
#             font-size:1em;">
#
# *The Goddard Rocket Problem:* We aim to Maximize the final altitude of a vertically launched rocket, using the thrust as a control
# and given the initial mass, the fuel mass, and the drag characteristics of the rocket.
# The problem is inspired from the following paper: [Benchmarking Optimization Software with COPS 3.0](https://www.mcs.anl.gov/~more/cops/cops3.pdf).
# We solve the problem using the [JuMP](https://jump.dev/) and [OptimalControl](https://control-toolbox.org/OptimalControl.jl/stable/) packages in Julia then we compare the results.
#
# 1. [JuMP Formulation](#jump)
# 2. [OptimalControl Formulation](#oc)
# 3. [Comparison](#comp)
#
# </div>

# %%
import Pkg
Pkg.activate("..")
include("./utils.jl");
using OptimalControlProblems
using Plots
using MKL
import HSL_jll
nh = 100;
# Out:
#   Activating project at `~/ENSEEIHT/Stage/CTBenchmarks.jl`

# %% [markdown]
# ## 1. Solving with JuMP <a id='jump'></a>

# %%
using JuMP, Ipopt

RocketJMP = rocket(JuMPBackend();nh=nh)

set_optimizer(RocketJMP,Ipopt.Optimizer)
set_attribute(RocketJMP, "print_level", 5)
set_optimizer_attribute(RocketJMP,"tol",1e-8)
set_optimizer_attribute(RocketJMP,"constr_viol_tol",1e-6)
set_optimizer_attribute(RocketJMP,"max_iter",1000)
set_optimizer_attribute(RocketJMP,"mu_strategy","adaptive")
#set_attribute(RocketJMP, "hsllib", HSL_jll.libhsl_path)
#set_attribute(RocketJMP, "linear_solver", "ma57")
set_optimizer_attribute(RocketJMP, "print_timing_statistics", "yes")

# %%
println("Solving...")
optimize!(RocketJMP)
println()

# Display results
if termination_status(RocketJMP) == MOI.OPTIMAL
    println("  Solution is optimal")
elseif  termination_status(RocketJMP) == MOI.LOCALLY_SOLVED
    println("  (Local) solution found")
elseif termination_status(RocketJMP) == MOI.TIME_LIMIT && has_values(RocketJMP)
    println("  Solution is suboptimal due to a time limit, but a primal solution is available")
else
    error("  The model was not solved correctly.")
end
println("  objective value = ", objective_value(RocketJMP))
println()

# Retrieves values (including duals - sign convention according to Pontrjagin max principle)
Δt = RocketJMP[:step]; 
h = RocketJMP[:h];
v = RocketJMP[:v];
m = RocketJMP[:m];
T = RocketJMP[:T];
con_dh = RocketJMP[:con_dh];
con_dv = RocketJMP[:con_dv];
con_dm = RocketJMP[:con_dm];
h_ic = RocketJMP[:h_ic];
v_ic = RocketJMP[:v_ic];
m_ic = RocketJMP[:m_ic];
m_fc = RocketJMP[:m_fc];

Δtt = value.(Δt)
t = Vector((0:nh)*Δtt);

ph0 = dual(h_ic)
pv0 = dual(v_ic)
pm0 = dual(m_ic)
pmf = dual(m_fc)

if(ph0*dual(con_dh[1])<0); ph0 = -ph0; end
if(pv0*dual(con_dv[1])<0); pv0 = -pv0; end
if(pm0*dual(con_dm[1])<0); pm0 = -pm0; end
if(pmf*dual(con_dm[nh])<0); pmf = -pmf; end

p = -[[ dual(con_dh[i]), dual(con_dv[i]), dual(con_dm[i]) ] for i in 1:nh];
p = costateInterpolation(p, t);

hh = Vector(value.(h)) ;
vv = Vector(value.(v)) ;
mm = Vector(value.(m)) ;
TT = Vector(value.(T)) ;

x =  [ [ hh[i], vv[i], mm[i] ] for i in 1:nh+1 ];
# Out:
# Solving...
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.17, running with linear solver MUMPS 5.8.0.
#
# Number of nonzeros in equality constraint Jacobian...:     2104
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     4900
#
# Total number of variables............................:      405
#                      variables with only lower bounds:      203
#                 variables with lower and upper bounds:      202
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      304
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.0100000e+00 3.50e-02 1.63e+00   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.0009573e+00 1.93e-02 3.36e+02  -1.5 1.45e+00    -  2.11e-01 4.34e-01h  1
#    2  1.0036899e+00 8.48e-03 1.41e+03  -2.2 1.67e+00    -  5.03e-01 6.64e-01h  1
#    3  1.0045431e+00 6.38e-03 1.45e+03  -2.0 1.25e+00    -  6.28e-01 8.87e-01h  1
#    4  1.0110605e+00 4.29e-03 7.20e+03  -1.5 8.03e-01    -  8.70e-02 9.90e-01f  1
#    5  1.0100610e+00 1.28e-04 1.48e+02  -2.0 5.52e-02    -  9.83e-01 9.95e-01f  1
#    6  1.0097789e+00 2.88e-06 2.05e+01  -3.2 8.33e-02    -  1.00e+00 1.00e+00h  1
#    7  1.0098418e+00 5.64e-08 2.34e-01  -4.6 3.12e-02    -  1.00e+00 1.00e+00h  1
#    8  1.0114487e+00 1.74e-04 1.36e-01  -5.2 9.05e-01    -  1.00e+00 1.00e+00h  1
#    9  1.0124863e+00 1.64e-04 4.16e+00  -5.7 6.11e-01    -  1.00e+00 9.91e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  1.0126628e+00 7.59e-05 2.05e-01  -5.9 8.38e-01    -  1.00e+00 9.98e-01h  1
#   11  1.0127794e+00 5.14e-05 2.44e-04  -6.4 8.29e-01    -  1.00e+00 1.00e+00h  1
#   12  1.0128215e+00 2.48e-05 3.08e-04  -7.1 8.27e-01    -  1.00e+00 1.00e+00h  1
#   13  1.0128308e+00 8.87e-06 1.22e-04  -8.0 9.47e-01    -  1.00e+00 1.00e+00h  1
#   14  1.0128318e+00 1.22e-06 1.73e-05  -8.8 3.77e-01    -  1.00e+00 1.00e+00h  1
#   15  1.0128319e+00 2.59e-08 8.18e-05  -9.2 7.31e-02    -  1.00e+00 9.99e-01h  1
#   16  1.0128320e+00 7.02e-09 2.31e-04 -10.3 4.29e-02    -  1.00e+00 9.96e-01h  1
#   17  1.0128320e+00 4.16e-10 2.62e-08 -10.7 4.05e-03    -  1.00e+00 1.00e+00h  1
#   18  1.0128320e+00 9.55e-11 2.52e-04 -11.0 6.04e-04    -  1.00e+00 7.81e-01h  1
#   19  1.0128320e+00 6.22e-13 4.21e-09 -11.0 1.53e-04    -  1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 19
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -1.0128320238051771e+00    1.0128320238051771e+00
# Dual infeasibility......:   4.2074741867675527e-09    4.2074741867675527e-09
# Constraint violation....:   6.2158611591200952e-13    6.2158611591200952e-13
# Variable bound violation:   1.6622608401907172e-40    1.6622608401907172e-40
# Complementarity.........:   1.1449953953483905e-11    1.1449953953483905e-11
# Overall NLP error.......:   4.2074741867675527e-09    4.2074741867675527e-09
#
#
# Number of objective function evaluations             = 20
# Number of objective gradient evaluations             = 20
# Number of equality constraint evaluations            = 20
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 20
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 19
# Total seconds in IPOPT (w/o function evaluations)    =      1.664
# Total seconds in NLP function evaluations            =      6.895
#
#
# Timing Statistics:
#
# OverallAlgorithm....................:      7.794 (sys:      1.699 wall:      8.558)
#  PrintProblemStatistics.............:      0.000 (sys:      0.000 wall:      0.000)
#  InitializeIterates.................:      1.479 (sys:      0.018 wall:      1.549)
#  UpdateHessian......................:      5.890 (sys:      1.665 wall:      6.723)
#  OutputIteration....................:      0.001 (sys:      0.000 wall:      0.001)
#  UpdateBarrierParameter.............:      0.159 (sys:      0.012 wall:      0.057)
#  ComputeSearchDirection.............:      0.028 (sys:      0.001 wall:      0.014)
#  ComputeAcceptableTrialPoint........:      0.028 (sys:      0.002 wall:      0.011)
#  AcceptTrialPoint...................:      0.001 (sys:      0.000 wall:      0.001)
#  CheckConvergence...................:      0.208 (sys:      0.002 wall:      0.203)
# PDSystemSolverTotal.................:      0.149 (sys:      0.008 wall:      0.058)
#  PDSystemSolverSolveOnce............:      0.133 (sys:      0.008 wall:      0.050)
#  ComputeResiduals...................:      0.014 (sys:      0.000 wall:      0.006)
#  StdAugSystemSolverMultiSolve.......:      0.124 (sys:      0.011 wall:      0.053)
#  LinearSystemScaling................:      0.000 (sys:      0.000 wall:      0.000)
#  LinearSystemSymbolicFactorization..:      0.001 (sys:      0.000 wall:      0.001)
#  LinearSystemFactorization..........:      0.000 (sys:      0.000 wall:      0.000)
#  LinearSystemBackSolve..............:      0.054 (sys:      0.001 wall:      0.016)
#  LinearSystemStructureConverter.....:      0.000 (sys:      0.000 wall:      0.000)
#   LinearSystemStructureConverterInit:      0.000 (sys:      0.000 wall:      0.000)
# QualityFunctionSearch...............:      0.028 (sys:      0.003 wall:      0.008)
# TryCorrector........................:      0.000 (sys:      0.000 wall:      0.000)
# Task1...............................:      0.014 (sys:      0.003 wall:      0.002)
# Task2...............................:      0.010 (sys:      0.001 wall:      0.003)
# Task3...............................:      0.000 (sys:      0.000 wall:      0.001)
# Task4...............................:      0.000 (sys:      0.000 wall:      0.000)
# Task5...............................:      0.001 (sys:      0.000 wall:      0.001)
# Task6...............................:      0.000 (sys:      0.000 wall:      0.000)
# Function Evaluations................:      6.055 (sys:      1.667 wall:      6.895)
#  Objective function.................:      0.048 (sys:      0.000 wall:      0.049)
#  Objective function gradient........:      0.000 (sys:      0.000 wall:      0.000)
#  Equality constraints...............:      0.115 (sys:      0.001 wall:      0.120)
#  Inequality constraints.............:      0.000 (sys:      0.000 wall:      0.000)
#  Equality constraint Jacobian.......:      0.003 (sys:      0.000 wall:      0.003)
#  Inequality constraint Jacobian.....:      0.000 (sys:      0.000 wall:      0.000)
#  Lagrangian Hessian.................:      5.889 (sys:      1.665 wall:      6.722)
#
# EXIT: Optimal Solution Found.
#
#   (Local) solution found
#   objective value = 1.0128320238051771

# %%
r_plot = plot(t, [ x[i][1] for i in 1:nh+1 ], xlabel = "t", ylabel = "h", legend = false)
v_plot = plot(t, [ x[i][2] for i in 1:nh+1 ], xlabel = "t", ylabel = "v", legend = false)
m_plot = plot(t, [ x[i][3] for i in 1:nh+1 ], xlabel = "t", ylabel = "m", legend = false)
pr_plot = plot(t, [ p[i][1] for i in 1:nh+1 ], xlabel = "t", ylabel = "ph", legend = false)
pv_plot = plot(t, [ p[i][2] for i in 1:nh+1 ], xlabel = "t", ylabel = "pv", legend = false)
pm_plot = plot(t, [ p[i][3] for i in 1:nh+1 ], xlabel = "t", ylabel = "pm", legend = false)
TT_plot = plot(t, [ TT[i] for i in 1:nh+1 ], xlabel = "t", ylabel = "TT", legend = false)

layout = @layout [a b; c d; e f; g]

x_plot = plot(r_plot, pr_plot, v_plot, pv_plot, m_plot, pm_plot, TT_plot, layout = layout)
display(x_plot)

# %% [markdown]
# ## 2. Solving with OptimalControl <a id='oc'></a>

# %%
using OptimalControl, NLPModelsIpopt
docp, RocketOC = rocket(OptimalControlBackend();nh=nh);

# %%
# Solve the problem
nlp_sol = NLPModelsIpopt.ipopt(
    RocketOC;
    print_level=5,
    tol=1e-8,
    mu_strategy="adaptive",
    sb="yes",
    constr_viol_tol=1e-6,
    max_iter=1000,
    print_timing_statistics="yes",
    #linear_solver="ma57",
    #hsllib=HSL_jll.libhsl_path,
)
# Out:
# This is Ipopt version 3.14.16, running with linear solver ma57.
#
# Number of nonzeros in equality constraint Jacobian...:     1904
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     1111
#
# Total number of variables............................:      405
#                      variables with only lower bounds:      203
#                 variables with lower and upper bounds:      202
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      304
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0 -1.0100000e+00 3.57e-01 2.00e+00   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1 -1.0686734e+00 2.74e-01 2.12e+01  -0.6 6.72e+00    -  5.15e-02 2.58e-01f  1
#    2 -1.0925348e+00 2.09e-01 9.88e+01   0.1 3.47e+00    -  5.18e-01 2.38e-01h  1
#    3 -1.0410984e+00 1.47e-01 9.31e+02   0.5 3.61e+00    -  8.66e-01 3.02e-01h  1
#    4 -1.0367439e+00 1.03e-01 5.63e+03   1.0 4.21e+00    -  1.00e+00 2.96e-01h  1
# Reallocating memory for MA57: lfact (16410)
#    5 -1.0115333e+00 1.93e-02 2.54e+04   1.5 1.69e+00    -  1.00e+00 8.14e-01h  1
# Reallocating memory for MA57: lfact (28902)
#    6 -1.0094968e+00 1.38e-02 1.29e+06   2.6 1.18e+01    -  9.79e-01 2.76e-01h  1
# Reallocating memory for MA57: lfact (53012)
#    7 -1.0086256e+00 6.48e-04 5.55e+04   2.3 1.28e+00    -  1.00e+00 9.90e-01f  1
#    8 -1.0077122e+00 5.91e-06 3.83e+04   0.9 5.02e-02    -  1.00e+00 9.93e-01h  1
#    9 -1.0077272e+00 3.50e-07 1.07e+02  -0.4 3.88e-02    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10 -1.0077296e+00 2.93e-08 7.45e-01  -2.5 8.44e-03    -  1.00e+00 1.00e+00h  1
#   11 -1.0077593e+00 2.55e-07 3.01e-02  -4.3 1.87e-02    -  1.00e+00 1.00e+00h  1
#   12 -1.0095463e+00 8.96e-04 2.14e+02  -4.8 1.88e+00    -  1.00e+00 9.27e-01h  1
#   13 -1.0112760e+00 2.85e-04 4.14e-03  -5.1 1.13e+00    -  1.00e+00 1.00e+00h  1
#   14 -1.0122597e+00 1.83e-04 2.01e+00  -5.4 6.92e-01    -  1.00e+00 9.94e-01h  1
#   15 -1.0126167e+00 1.16e-04 2.16e+00  -5.8 7.87e-01    -  1.00e+00 9.92e-01h  1
#   16 -1.0127618e+00 7.56e-05 9.66e-01  -6.3 9.39e-01    -  1.00e+00 9.91e-01h  1
#   17 -1.0128196e+00 3.44e-05 1.01e-04  -7.0 1.07e+00    -  1.00e+00 1.00e+00h  1
#   18 -1.0128306e+00 1.21e-05 2.49e-05  -7.9 1.06e+00    -  1.00e+00 1.00e+00h  1
#   19 -1.0128318e+00 1.70e-06 2.59e-06  -8.7 4.49e-01    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20 -1.0128319e+00 4.51e-08 1.51e-04  -9.0 7.97e-02    -  1.00e+00 9.98e-01h  1
#   21 -1.0128320e+00 9.00e-09 5.51e-08 -10.2 5.00e-02    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 21
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -1.0128320181597095e+00   -1.0128320181597095e+00
# Dual infeasibility......:   5.5139931528912112e-08    5.5139931528912112e-08
# Constraint violation....:   7.8385083979171100e-09    8.9990002671846980e-09
# Variable bound violation:   2.0308623710367820e-33    2.0308623710367820e-33
# Complementarity.........:   7.0993602449957000e-10    7.0993602449957000e-10
# Overall NLP error.......:   7.8385083979171100e-09    5.5139931528912112e-08
#
#
# Number of objective function evaluations             = 22
# Number of objective gradient evaluations             = 22
# Number of equality constraint evaluations            = 22
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 22
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 21
# Total seconds in IPOPT (w/o function evaluations)    =      1.259
# Total seconds in NLP function evaluations            =      1.678
#
#
# Timing Statistics:
#
# OverallAlgorithm....................:      2.937 (sys:      0.000 wall:      2.937)
#  PrintProblemStatistics.............:      0.000 (sys:      0.000 wall:      0.000)
#  InitializeIterates.................:      1.207 (sys:      0.000 wall:      1.207)
#  UpdateHessian......................:      1.139 (sys:      0.000 wall:      1.140)
#  OutputIteration....................:      0.005 (sys:      0.000 wall:      0.002)
#  UpdateBarrierParameter.............:      0.030 (sys:      0.000 wall:      0.033)
#  ComputeSearchDirection.............:      0.005 (sys:      0.000 wall:      0.005)
#  ComputeAcceptableTrialPoint........:      0.019 (sys:      0.000 wall:      0.016)
#  AcceptTrialPoint...................:      0.000 (sys:      0.000 wall:      0.001)
#  CheckConvergence...................:      0.532 (sys:      0.000 wall:      0.534)
# PDSystemSolverTotal.................:      0.030 (sys:      0.000 wall:      0.031)
#  PDSystemSolverSolveOnce............:      0.027 (sys:      0.000 wall:      0.028)
#  ComputeResiduals...................:      0.002 (sys:      0.000 wall:      0.001)
#  StdAugSystemSolverMultiSolve.......:      0.026 (sys:      0.000 wall:      0.026)
#  LinearSystemScaling................:      0.000 (sys:      0.000 wall:      0.000)
#  LinearSystemSymbolicFactorization..:      0.000 (sys:      0.000 wall:      0.000)
#  LinearSystemFactorization..........:      0.019 (sys:      0.000 wall:      0.018)
#  LinearSystemBackSolve..............:      0.002 (sys:      0.000 wall:      0.004)
#  LinearSystemStructureConverter.....:      0.000 (sys:      0.000 wall:      0.000)
#   LinearSystemStructureConverterInit:      0.000 (sys:      0.000 wall:      0.000)
# QualityFunctionSearch...............:      0.001 (sys:      0.000 wall:      0.002)
# TryCorrector........................:      0.000 (sys:      0.000 wall:      0.000)
# Task1...............................:      0.001 (sys:      0.000 wall:      0.001)
# Task2...............................:      0.000 (sys:      0.000 wall:      0.001)
# Task3...............................:      0.000 (sys:      0.000 wall:      0.000)
# Task4...............................:      0.000 (sys:      0.000 wall:      0.000)
# Task5...............................:      0.000 (sys:      0.000 wall:      0.000)
# Task6...............................:      0.000 (sys:      0.000 wall:      0.000)
# Function Evaluations................:      1.676 (sys:      0.000 wall:      1.678)
#  Objective function.................:      0.057 (sys:      0.000 wall:      0.058)
#  Objective function gradient........:      0.000 (sys:      0.000 wall:      0.001)
#  Equality constraints...............:      0.425 (sys:      0.000 wall:      0.424)
#  Inequality constraints.............:      0.000 (sys:      0.000 wall:      0.000)
#  Equality constraint Jacobian.......:      0.057 (sys:      0.000 wall:      0.056)
#  Inequality constraint Jacobian.....:      0.000 (sys:      0.000 wall:      0.000)
#  Lagrangian Hessian.................:      1.137 (sys:      0.000 wall:      1.138)
#
# EXIT: Optimal Solution Found.
# "Execution stats: first-order stationary"

# %%
# Plot results
sol = build_OCP_solution(docp; primal=nlp_sol.solution, dual=nlp_sol.multipliers)
plot(sol)

# %% [markdown]
# ## 3. Comparison <a id='comp'></a>

# %%
p1 = plot(plot(sol)[1],line = 2)
p1 = plot!(t, [ x[i][1] for i in 1:nh+1 ], xlabel = "t", ylabel = "h", legend = false,line = 2, color = "red",linestyle=:dash)

p3 = plot(plot(sol)[2],line = 2)
p3 = plot!(t, [ x[i][2] for i in 1:nh+1 ], xlabel = "t", ylabel = "v", legend = false,line = 2, color = "red",linestyle=:dash)

p5 = plot(plot(sol)[3],line = 2)
p5 = plot!(t, [ x[i][3] for i in 1:nh+1 ], xlabel = "t", ylabel = "m", legend = false,line = 2, color = "red",linestyle=:dash)

p2 = plot(plot(sol)[4],line = 2)
p2 = plot!(t, [ p[i][1] for i in 1:nh+1 ], xlabel = "t", ylabel = "ph", legend = false,line = 2, color = "red",linestyle=:dash)

p4 = plot(plot(sol)[5],line = 2)
p4 = plot!(t, [ p[i][2] for i in 1:nh+1 ], xlabel = "t", ylabel = "pv", legend = false,line = 2, color = "red",linestyle=:dash)

p6 = plot(plot(sol)[6],line = 2)
p6 = plot!(t, [ p[i][3] for i in 1:nh+1 ], xlabel = "t", ylabel = "pm", legend = false,line = 2, color = "red",linestyle=:dash)

p7 = plot(plot(sol)[7] , label ="OC",line = 2)
p7 = plot!(t, [ TT[i] for i in 1:nh+1 ], xlabel = "t", ylabel = "T", legend = false, label = "JuMP",line = 2, color = "red",linestyle=:dash)
p7 = plot!(legend=:outerbottom, legendcolumns=2)

layout = @layout [a b; c d; e f; g]

x_plot = plot(p1, p2, p3, p4, p5, p6, p7, layout = layout)
x_plot = plot!(size = (700, 700))

display(x_plot)

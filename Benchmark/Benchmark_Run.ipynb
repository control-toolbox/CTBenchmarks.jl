# %%
include("./Benchmark.jl")
# Out:
#   Activating project at `c:\Users\hajje\Dropbox\PC\Desktop\Stage\COTS`
# Main.Benchmark

# %%
Benchmark.Benchmark_JuMP()
# Out:
# Benchmarking the model cart_pendulum ... ✅
# Benchmarking the model truck ... ❌
# Benchmarking the model robot ... ✅
# Benchmarking the model quadrotorp2p ... ❌
# Benchmarking the model quadrotor1obs ... ❌
# Benchmarking the model electrical_vehicle ... ✅
# Benchmarking the model moonlander ... ❌
# Benchmarking the model double_oscillator ... ✅
# Benchmarking the model ducted_fan ... ✅
# Benchmarking the model steering ... ✅
# Benchmarking the model glider ... ❌
# Benchmarking the model rocket ... ✅
# Benchmarking the model chain ... ✅
# Benchmarking the model dielectrophoretic_particle ... ✅
# Benchmarking the model space_shuttle ... ❌

# %%
Benchmark.Benchmark_OC()
# Out:
# Benchmarking the model cart_pendulum ... ✅
# Benchmarking the model truck ... ❌
# Benchmarking the model robot ... ✅
# Benchmarking the model quadrotorp2p ... ❌
# Benchmarking the model electrical_vehicle ... ✅
# Benchmarking the model moonlander ... ❌
# Benchmarking the model double_oscillator ... ✅
# Benchmarking the model ducted_fan ... ✅
# Benchmarking the model steering ... ✅
# Benchmarking the model glider ... ❌
# Benchmarking the model rocket ... ✅
# Benchmarking the model chain ... ✅
# ...

# %%
Benchmark.Benchmark_model(:glider;display=true)
# Out:
# Benchmarking the model glider with OptimalControl (100)... Method = (:direct, :adnlp, :ipopt)
# ✅
# Benchmarking the model glider with JuMP (100)... This is Ipopt version 3.14.14, running with linear solver ma57.
#
# Number of nonzeros in equality constraint Jacobian...:     3007
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     9400
#
# Total number of variables............................:      506
#                      variables with only lower bounds:      203
#                 variables with lower and upper bounds:      101
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      407
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
# ...

# %% [markdown]
# -----

# %%
Benchmark.Benchmark_Callbacks(:rocket , [500;100])
# Out:
# Benchmarking the model rocket with OptimalControl (500)... ✅
# Benchmarking the model rocket with JuMP (500)... ✅
# Benchmarking the model rocket with OptimalControl (100)... ✅
# Benchmarking the model rocket with JuMP (100)... ✅
